# %% [markdown]
# <a href="https://colab.research.google.com/github/reyanshgupta/SEM_5_IVP/blob/main/IVP_Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
img_python = cv2.imread('python.png')

# %%
cv2_imshow(img_python)
# Out:
# <PIL.Image.Image image mode=RGB size=768x493>

# %%
img_python
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img_python.shape
# Out:
# (493, 768, 3)

# %%
img_python_bw = cv2.imread('python.png',0)

# %%
img_python_bw
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
cv2_imshow(img_python_bw)
# Out:
# <PIL.Image.Image image mode=L size=768x493>

# %%
img_python_bw.shape
# Out:
# (493, 768)

# %%
img_python_uc = cv2.imread('python.png',-1)
cv2_imshow(img_python_uc)
img_python_uc.shape
# Out:
# <PIL.Image.Image image mode=RGB size=768x493>
# (493, 768, 3)

# %%
img_python_uc
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# **Plots:**

# %%
plt.imshow(img_python_bw)

# %%
gray_image = cv2.cvtColor(img_python, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image)

# %%
gray_image_2 = cv2.cvtColor(gray_image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(gray_image_2)

# %%
gray_image_2.shape
# Out:
# (493, 768, 3)

# %% [markdown]
# **Threshold**

# %%
ret,bin_image=cv2.threshold(gray_image, 127,255,0)

# %%
bin_image
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
cv2_imshow(bin_image)
# Out:
# <PIL.Image.Image image mode=L size=768x493>

# %%
b,g,r = cv2.split(img_python)
cv2_imshow(img_python)
k = np.zeros_like(b)
b = cv2.merge([b,k,k])
g = cv2.merge([k,g,k])
r = cv2.merge([k,k,r])
cv2_imshow(r)
cv2_imshow(g)
cv2_imshow(b)

# %%
half = cv2.resize(img_python, (0,0), fx=0.1, fy=0.1)
bigger=cv2.resize(img_python, (1050,1610))

# %%
cv2_imshow(half)
cv2_imshow(bigger)

# %%
adjusted = cv2.convertedScaleAbs(img_python,alpha=1,beta=1)
