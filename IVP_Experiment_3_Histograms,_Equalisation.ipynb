# %% [markdown]
# <a href="https://colab.research.google.com/github/reyanshgupta/SEM_5_IVP/blob/main/IVP_Experiment_3_Histograms%2C_Equalisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
img_python = cv2.imread('python.png')
img_python_bw = cv2.imread('python.png',0)
cv2_imshow(img_python)
cv2_imshow(img_python_bw)
# Out:
# <PIL.Image.Image image mode=RGB size=1400x949>
# <PIL.Image.Image image mode=L size=1400x949>

# %%
minI = img_python_bw.min()
maxI = img_python_bw.max()

# %%
min0=0
max0=100
k,l = img_python_bw.shape
new = np.zeros((k,l),dtype=np.uint8)
for i in range(k):
  for j in range(l):
    new[i,j]=(int)(img_python_bw[i,j]-minI)*(((max0-min0)/(maxI-minI))+min0)
cv2_imshow(new)
# Out:
# <PIL.Image.Image image mode=L size=1400x949>

# %%
hist = cv2.calcHist([img_python_bw],[0],None,[256],[0,256])
plt.plot(hist)

# %%
hist2 = cv2.calcHist([new],[0],None,[256],[0,256])
plt.plot(hist2)

# %%
equ = cv2.equalizeHist(img_python_bw)
hist = cv2.calcHist([equ],[0],None,[256],[0,256])
plt.plot(hist)
